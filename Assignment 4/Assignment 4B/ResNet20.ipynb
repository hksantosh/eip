# %% [markdown]
# <a href="https://colab.research.google.com/github/hksantosh/eip/blob/master/Assignment%204/Assignment%204B/ResNet20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation , Dropout
from keras.layers import AveragePooling2D, Input, Flatten ,GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint,LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# %%
batch_size = 128  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = True
num_classes = 10

# %%
#Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 2

# %%
#Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
#Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
import numpy as np


def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
def resnet_layer(inputs,
                 num_filters=22,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization(momentum=0.355)(x)
            x=Dropout(0.0994)(x)
          #  x=Dropout(0.13)(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization(momentum=0.355)(x)
            x=Dropout(0.0994)(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 22
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
   # x = AveragePooling2D(pool_size=4)(x)
    y = GlobalAveragePooling2D()(x)
    #outputs=Activation('softmax')(y)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)
# Out:
# Learning rate:  0.001
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 32, 32, 22)   616         input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 32, 32, 22)   88          conv2d_61[0][0]
# __________________________________________________________________________________________________
# dropout_53 (Dropout)            (None, 32, 32, 22)   0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 32, 32, 22)   0           dropout_53[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 32, 32, 22)   4378        activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 32, 32, 22)   88          conv2d_62[0][0]
# __________________________________________________________________________________________________
# dropout_54 (Dropout)            (None, 32, 32, 22)   0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 32, 32, 22)   0           dropout_54[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 32, 32, 22)   4378        activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 32, 32, 22)   88          conv2d_63[0][0]
# __________________________________________________________________________________________________
# dropout_55 (Dropout)            (None, 32, 32, 22)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 32, 32, 22)   0           activation_53[0][0]
#                                                                  dropout_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 32, 32, 22)   0           add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 32, 32, 22)   4378        activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 32, 32, 22)   88          conv2d_64[0][0]
# __________________________________________________________________________________________________
# dropout_56 (Dropout)            (None, 32, 32, 22)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 32, 32, 22)   0           dropout_56[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 32, 32, 22)   4378        activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 32, 32, 22)   88          conv2d_65[0][0]
# __________________________________________________________________________________________________
# dropout_57 (Dropout)            (None, 32, 32, 22)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 32, 32, 22)   0           activation_55[0][0]
#                                                                  dropout_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 32, 32, 22)   0           add_26[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 16, 16, 44)   8756        activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 16, 16, 44)   176         conv2d_66[0][0]
# __________________________________________________________________________________________________
# dropout_58 (Dropout)            (None, 16, 16, 44)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 16, 16, 44)   0           dropout_58[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 16, 16, 44)   17468       activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 16, 16, 44)   176         conv2d_67[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 16, 16, 44)   1012        activation_57[0][0]
# __________________________________________________________________________________________________
# dropout_59 (Dropout)            (None, 16, 16, 44)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 16, 16, 44)   0           conv2d_68[0][0]
#                                                                  dropout_59[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 16, 16, 44)   0           add_27[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 16, 16, 44)   17468       activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 16, 16, 44)   176         conv2d_69[0][0]
# __________________________________________________________________________________________________
# dropout_60 (Dropout)            (None, 16, 16, 44)   0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 16, 16, 44)   0           dropout_60[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 16, 16, 44)   17468       activation_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 16, 16, 44)   176         conv2d_70[0][0]
# __________________________________________________________________________________________________
# dropout_61 (Dropout)            (None, 16, 16, 44)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 16, 16, 44)   0           activation_59[0][0]
#                                                                  dropout_61[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 16, 16, 44)   0           add_28[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 88)     34936       activation_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 8, 8, 88)     352         conv2d_71[0][0]
# __________________________________________________________________________________________________
# dropout_62 (Dropout)            (None, 8, 8, 88)     0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 8, 8, 88)     0           dropout_62[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 8, 8, 88)     69784       activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 8, 8, 88)     352         conv2d_72[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 8, 8, 88)     3960        activation_61[0][0]
# __________________________________________________________________________________________________
# dropout_63 (Dropout)            (None, 8, 8, 88)     0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 8, 8, 88)     0           conv2d_73[0][0]
#                                                                  dropout_63[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 8, 8, 88)     0           add_29[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 8, 8, 88)     69784       activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 8, 8, 88)     352         conv2d_74[0][0]
# __________________________________________________________________________________________________
# dropout_64 (Dropout)            (None, 8, 8, 88)     0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 8, 8, 88)     0           dropout_64[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 88)     69784       activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 8, 8, 88)     352         conv2d_75[0][0]
# __________________________________________________________________________________________________
# dropout_65 (Dropout)            (None, 8, 8, 88)     0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 8, 8, 88)     0           activation_63[0][0]
#                                                                  dropout_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 8, 8, 88)     0           add_30[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 88)           0           activation_65[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 10)           890         global_average_pooling2d_5[0][0]
# ==================================================================================================
# Total params: 331,990
# Trainable params: 330,714
# Non-trainable params: 1,276
# __________________________________________________________________________________________________
# ResNet14v1

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=2,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
#Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    get_random_eraser(v_l=0, v_h=1)
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        
       # get_random_eraser(v_l=0, v_h=1)
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)
# Out:
# Using real-time data augmentation.

# %%
#Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs,verbose=2,workers=4,
                        callbacks=callbacks)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Epoch 1/50
# Learning rate:  0.001
#  - 35s - loss: 1.7259 - acc: 0.4235 - val_loss: 1.3928 - val_acc: 0.5485
#
# Epoch 00001: val_acc improved from -inf to 0.54850, saving model to /content/saved_models/cifar10_ResNet14v1_model.001.h5
# Epoch 2/50
# Learning rate:  0.001
#  - 27s - loss: 1.3283 - acc: 0.5738 - val_loss: 1.1446 - val_acc: 0.6431
#
# Epoch 00002: val_acc improved from 0.54850 to 0.64310, saving model to /content/saved_models/cifar10_ResNet14v1_model.002.h5
# Epoch 3/50
# Learning rate:  0.001
#  - 27s - loss: 1.1621 - acc: 0.6390 - val_loss: 1.0591 - val_acc: 0.6769
#
# Epoch 00003: val_acc improved from 0.64310 to 0.67690, saving model to /content/saved_models/cifar10_ResNet14v1_model.003.h5
# Epoch 4/50
# Learning rate:  0.001
#  - 27s - loss: 1.0420 - acc: 0.6813 - val_loss: 0.9398 - val_acc: 0.7205
#
# Epoch 00004: val_acc improved from 0.67690 to 0.72050, saving model to /content/saved_models/cifar10_ResNet14v1_model.004.h5
# Epoch 5/50
# Learning rate:  0.001
#  - 27s - loss: 0.9575 - acc: 0.7121 - val_loss: 0.9332 - val_acc: 0.7273
#
# Epoch 00005: val_acc improved from 0.72050 to 0.72730, saving model to /content/saved_models/cifar10_ResNet14v1_model.005.h5
# Epoch 6/50
# Learning rate:  0.001
#  - 27s - loss: 0.8964 - acc: 0.7354 - val_loss: 0.8119 - val_acc: 0.7690
#
# Epoch 00006: val_acc improved from 0.72730 to 0.76900, saving model to /content/saved_models/cifar10_ResNet14v1_model.006.h5
# Epoch 7/50
# Learning rate:  0.001
#  - 27s - loss: 0.8411 - acc: 0.7551 - val_loss: 0.7843 - val_acc: 0.7809
#
# Epoch 00007: val_acc improved from 0.76900 to 0.78090, saving model to /content/saved_models/cifar10_ResNet14v1_model.007.h5
# Epoch 8/50
# Learning rate:  0.001
#  - 27s - loss: 0.8054 - acc: 0.7694 - val_loss: 0.7550 - val_acc: 0.7888
#
# Epoch 00008: val_acc improved from 0.78090 to 0.78880, saving model to /content/saved_models/cifar10_ResNet14v1_model.008.h5
# Epoch 9/50
# Learning rate:  0.001
#  - 27s - loss: 0.7719 - acc: 0.7803 - val_loss: 0.7663 - val_acc: 0.7904
#
# Epoch 00009: val_acc improved from 0.78880 to 0.79040, saving model to /content/saved_models/cifar10_ResNet14v1_model.009.h5
# Epoch 10/50
# Learning rate:  0.001
#  - 27s - loss: 0.7443 - acc: 0.7912 - val_loss: 0.6852 - val_acc: 0.8144
#
# Epoch 00010: val_acc improved from 0.79040 to 0.81440, saving model to /content/saved_models/cifar10_ResNet14v1_model.010.h5
# Epoch 11/50
# Learning rate:  0.001
#  - 28s - loss: 0.7130 - acc: 0.8019 - val_loss: 0.6956 - val_acc: 0.8087
#
# Epoch 00011: val_acc did not improve from 0.81440
# Epoch 12/50
# Learning rate:  0.001
#  - 28s - loss: 0.7019 - acc: 0.8060 - val_loss: 0.6757 - val_acc: 0.8186
#
# Epoch 00012: val_acc improved from 0.81440 to 0.81860, saving model to /content/saved_models/cifar10_ResNet14v1_model.012.h5
# Epoch 13/50
# Learning rate:  0.001
#  - 28s - loss: 0.6808 - acc: 0.8138 - val_loss: 0.6584 - val_acc: 0.8286
#
# Epoch 00013: val_acc improved from 0.81860 to 0.82860, saving model to /content/saved_models/cifar10_ResNet14v1_model.013.h5
# Epoch 14/50
# Learning rate:  0.001
#  - 28s - loss: 0.6644 - acc: 0.8185 - val_loss: 0.6368 - val_acc: 0.8323
#
# Epoch 00014: val_acc improved from 0.82860 to 0.83230, saving model to /content/saved_models/cifar10_ResNet14v1_model.014.h5
# Epoch 15/50
# Learning rate:  0.001
#  - 28s - loss: 0.6501 - acc: 0.8239 - val_loss: 0.6570 - val_acc: 0.8229
#
# Epoch 00015: val_acc did not improve from 0.83230
# Epoch 16/50
# Learning rate:  0.001
#  - 28s - loss: 0.6401 - acc: 0.8276 - val_loss: 0.6003 - val_acc: 0.8409
#
# Epoch 00016: val_acc improved from 0.83230 to 0.84090, saving model to /content/saved_models/cifar10_ResNet14v1_model.016.h5
# Epoch 17/50
# Learning rate:  0.001
#  - 28s - loss: 0.6296 - acc: 0.8310 - val_loss: 0.5958 - val_acc: 0.8497
#
# Epoch 00017: val_acc improved from 0.84090 to 0.84970, saving model to /content/saved_models/cifar10_ResNet14v1_model.017.h5
# Epoch 18/50
# Learning rate:  0.001
#  - 28s - loss: 0.6122 - acc: 0.8366 - val_loss: 0.6167 - val_acc: 0.8432
#
# Epoch 00018: val_acc did not improve from 0.84970
# Epoch 19/50
# Learning rate:  0.001
#  - 28s - loss: 0.6014 - acc: 0.8410 - val_loss: 0.6182 - val_acc: 0.8434
#
# Epoch 00019: val_acc did not improve from 0.84970
# Epoch 20/50
# Learning rate:  0.001
#  - 27s - loss: 0.5939 - acc: 0.8431 - val_loss: 0.6206 - val_acc: 0.8417
#
# Epoch 00020: val_acc did not improve from 0.84970
# Epoch 21/50
# Learning rate:  0.001
#  - 27s - loss: 0.5842 - acc: 0.8480 - val_loss: 0.5766 - val_acc: 0.8554
#
# Epoch 00021: val_acc improved from 0.84970 to 0.85540, saving model to /content/saved_models/cifar10_ResNet14v1_model.021.h5
# Epoch 22/50
# Learning rate:  0.001
#  - 27s - loss: 0.5806 - acc: 0.8480 - val_loss: 0.5707 - val_acc: 0.8603
#
# Epoch 00022: val_acc improved from 0.85540 to 0.86030, saving model to /content/saved_models/cifar10_ResNet14v1_model.022.h5
# Epoch 23/50
# Learning rate:  0.001
#  - 27s - loss: 0.5671 - acc: 0.8546 - val_loss: 0.5659 - val_acc: 0.8611
#
# Epoch 00023: val_acc improved from 0.86030 to 0.86110, saving model to /content/saved_models/cifar10_ResNet14v1_model.023.h5
# Epoch 24/50
# Learning rate:  0.001
#  - 27s - loss: 0.5667 - acc: 0.8550 - val_loss: 0.5791 - val_acc: 0.8550
#
# Epoch 00024: val_acc did not improve from 0.86110
# Epoch 25/50
# Learning rate:  0.001
#  - 27s - loss: 0.5574 - acc: 0.8582 - val_loss: 0.5820 - val_acc: 0.8594
#
# Epoch 00025: val_acc did not improve from 0.86110
# Epoch 26/50
# Learning rate:  0.001
#  - 27s - loss: 0.5539 - acc: 0.8588 - val_loss: 0.5776 - val_acc: 0.8581
#
# Epoch 00026: val_acc did not improve from 0.86110
# Epoch 27/50
# Learning rate:  0.001
#  - 27s - loss: 0.5441 - acc: 0.8642 - val_loss: 0.6024 - val_acc: 0.8507
#
# Epoch 00027: val_acc did not improve from 0.86110
# Epoch 28/50
# Learning rate:  0.001
#  - 27s - loss: 0.5459 - acc: 0.8628 - val_loss: 0.5423 - val_acc: 0.8671
#
# Epoch 00028: val_acc improved from 0.86110 to 0.86710, saving model to /content/saved_models/cifar10_ResNet14v1_model.028.h5
# Epoch 29/50
# Learning rate:  0.001
#  - 27s - loss: 0.5379 - acc: 0.8642 - val_loss: 0.5467 - val_acc: 0.8689
#
# Epoch 00029: val_acc improved from 0.86710 to 0.86890, saving model to /content/saved_models/cifar10_ResNet14v1_model.029.h5
# Epoch 30/50
# Learning rate:  0.001
#  - 27s - loss: 0.5322 - acc: 0.8687 - val_loss: 0.5620 - val_acc: 0.8670
#
# Epoch 00030: val_acc did not improve from 0.86890
# Epoch 31/50
# Learning rate:  0.001
#  - 27s - loss: 0.5309 - acc: 0.8680 - val_loss: 0.5241 - val_acc: 0.8740
#
# Epoch 00031: val_acc improved from 0.86890 to 0.87400, saving model to /content/saved_models/cifar10_ResNet14v1_model.031.h5
# Epoch 32/50
# Learning rate:  0.001
#  - 27s - loss: 0.5212 - acc: 0.8730 - val_loss: 0.5344 - val_acc: 0.8726
#
# Epoch 00032: val_acc did not improve from 0.87400
# Epoch 33/50
# Learning rate:  0.001
#  - 27s - loss: 0.5227 - acc: 0.8710 - val_loss: 0.5421 - val_acc: 0.8721
#
# Epoch 00033: val_acc did not improve from 0.87400
# Epoch 34/50
# Learning rate:  0.001
#  - 27s - loss: 0.5177 - acc: 0.8736 - val_loss: 0.5343 - val_acc: 0.8740
#
# Epoch 00034: val_acc did not improve from 0.87400
# Epoch 35/50
# Learning rate:  0.001
#  - 27s - loss: 0.5158 - acc: 0.8723 - val_loss: 0.5223 - val_acc: 0.8790
#
# Epoch 00035: val_acc improved from 0.87400 to 0.87900, saving model to /content/saved_models/cifar10_ResNet14v1_model.035.h5
# Epoch 36/50
# Learning rate:  0.001
#  - 27s - loss: 0.5111 - acc: 0.8753 - val_loss: 0.5353 - val_acc: 0.8753
#
# Epoch 00036: val_acc did not improve from 0.87900
# Epoch 37/50
# Learning rate:  0.001
#  - 27s - loss: 0.5041 - acc: 0.8766 - val_loss: 0.5480 - val_acc: 0.8702
#
# Epoch 00037: val_acc did not improve from 0.87900
# Epoch 38/50
# Learning rate:  0.001
#  - 27s - loss: 0.5093 - acc: 0.8764 - val_loss: 0.5446 - val_acc: 0.8717
#
# Epoch 00038: val_acc did not improve from 0.87900
# Epoch 39/50
# Learning rate:  0.001
#  - 27s - loss: 0.4981 - acc: 0.8793 - val_loss: 0.5413 - val_acc: 0.8725
#
# Epoch 00039: val_acc did not improve from 0.87900
# Epoch 40/50
# Learning rate:  0.001
#  - 27s - loss: 0.4943 - acc: 0.8815 - val_loss: 0.5179 - val_acc: 0.8831
#
# Epoch 00040: val_acc improved from 0.87900 to 0.88310, saving model to /content/saved_models/cifar10_ResNet14v1_model.040.h5
# Epoch 41/50
# Learning rate:  0.001
#  - 27s - loss: 0.4934 - acc: 0.8820 - val_loss: 0.5586 - val_acc: 0.8699
#
# Epoch 00041: val_acc did not improve from 0.88310
# Epoch 42/50
# Learning rate:  0.001
#  - 27s - loss: 0.4945 - acc: 0.8832 - val_loss: 0.5246 - val_acc: 0.8766
#
# Epoch 00042: val_acc did not improve from 0.88310
# Epoch 43/50
# Learning rate:  0.001
#  - 27s - loss: 0.4970 - acc: 0.8802 - val_loss: 0.5183 - val_acc: 0.8821
#
# Epoch 00043: val_acc did not improve from 0.88310
# Epoch 44/50
# Learning rate:  0.001
#  - 27s - loss: 0.4932 - acc: 0.8830 - val_loss: 0.5420 - val_acc: 0.8771
#
# Epoch 00044: val_acc did not improve from 0.88310
# Epoch 45/50
# Learning rate:  0.001
#  - 27s - loss: 0.4895 - acc: 0.8821 - val_loss: 0.5479 - val_acc: 0.8700
#
# Epoch 00045: val_acc did not improve from 0.88310
# Epoch 46/50
# Learning rate:  0.001
#  - 27s - loss: 0.4852 - acc: 0.8857 - val_loss: 0.5278 - val_acc: 0.8755
#
# Epoch 00046: val_acc did not improve from 0.88310
# Epoch 47/50
# Learning rate:  0.001
#  - 27s - loss: 0.4842 - acc: 0.8868 - val_loss: 0.5215 - val_acc: 0.8762
#
# Epoch 00047: val_acc did not improve from 0.88310
# Epoch 48/50
# Learning rate:  0.001
#  - 27s - loss: 0.4810 - acc: 0.8877 - val_loss: 0.5358 - val_acc: 0.8738
#
# Epoch 00048: val_acc did not improve from 0.88310
# Epoch 49/50
# Learning rate:  0.001
#  - 27s - loss: 0.4818 - acc: 0.8875 - val_loss: 0.5379 - val_acc: 0.8796
#
# Epoch 00049: val_acc did not improve from 0.88310
# Epoch 50/50
# Learning rate:  0.001
#  - 27s - loss: 0.4793 - acc: 0.8869 - val_loss: 0.5480 - val_acc: 0.8705
#
# Epoch 00050: val_acc did not improve from 0.88310
# 10000/10000 [==============================] - 1s 145us/step
# Test loss: 0.5479556740283966
# Test accuracy: 0.8705

# %%
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.preprocessing import image
import numpy as np
import cv2
from keras import backend as K
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from keras.datasets import cifar10
from google.colab.patches import cv2_imshow
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
#Input image dimensions.
#input_shape = x_train.shape[1:]

# Normalize data.
#x_train = x_train.astype('float32') / 255
#x_test = x_test.astype('float32') / 255

#x=y_train.shape[0]
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
#model = VGG16(weights="imagenet")
from skimage import io
#dog = io.imread("https://www.rspcapetinsurance.org.au/rspca/media/images/hero/dog-insurance-hero.jpg")
img1=cv2.resize(x_train[0],dsize=(32,32),interpolation=cv2.INTER_CUBIC)
#dog = cv2.resize(dog, dsize=(224, 224), interpolation=cv2.INTER_CUBIC)
x = image.img_to_array(img1)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
plt.imshow(img1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-ee76b5a5ac84> in <module>()
# ----> 1 from skimage import io
#       2 #dog = io.imread("https://www.rspcapetinsurance.org.au/rspca/media/images/hero/dog-insurance-hero.jpg")
#       3 img1=cv2.resize(x_train[0],dsize=(32,32),interpolation=cv2.INTER_CUBIC)
#       4 #dog = cv2.resize(dog, dsize=(224, 224), interpolation=cv2.INTER_CUBIC)
#       5 x = image.img_to_array(img1)
#
# /usr/local/lib/python3.6/dist-packages/skimage/__init__.py in <module>()
#     133                              img_as_bool,
#     134                              dtype_limits)
# --> 135     from .data import data_dir
#     136     from .util.lookfor import lookfor
#     137
#
# /usr/local/lib/python3.6/dist-packages/skimage/data/__init__.py in <module>()
#      14 from .._shared._warnings import expected_warnings, warn
#      15 from ..util.dtype import img_as_bool
# ---> 16 from ._binary_blobs import binary_blobs
#      17 from ._detect import lbp_frontal_face_cascade_filename
#      18
#
# /usr/local/lib/python3.6/dist-packages/skimage/data/_binary_blobs.py in <module>()
#       1 import numpy as np
# ----> 2 from ..filters import gaussian
#       3
#       4
#       5 def binary_blobs(length=512, blob_size_fraction=0.1, n_dim=2,
#
# /usr/local/lib/python3.6/dist-packages/skimage/filters/__init__.py in <module>()
#       1 from .lpi_filter import inverse, wiener, LPIFilter2D
#       2 from ._gaussian import gaussian
# ----> 3 from .edges import (sobel, sobel_h, sobel_v,
#       4                     scharr, scharr_h, scharr_v,
#       5                     prewitt, prewitt_h, prewitt_v,
#
# /usr/local/lib/python3.6/dist-packages/skimage/filters/edges.py in <module>()
#      15 from scipy.ndimage import convolve, binary_erosion, generate_binary_structure
#      16
# ---> 17 from ..restoration.uft import laplacian
#      18
#      19 EROSION_SELEM = generate_binary_structure(2, 2)
#
# /usr/local/lib/python3.6/dist-packages/skimage/restoration/__init__.py in <module>()
#       5 from .deconvolution import wiener, unsupervised_wiener, richardson_lucy
#       6 from .unwrap import unwrap_phase
# ----> 7 from ._denoise import (denoise_tv_chambolle, denoise_tv_bregman,
#       8                        denoise_bilateral, denoise_wavelet, estimate_sigma)
#       9 from ._cycle_spin import cycle_spin
#
# /usr/local/lib/python3.6/dist-packages/skimage/restoration/_denoise.py in <module>()
#       7 from .._shared.utils import warn
#       8 import pywt
# ----> 9 import skimage.color as color
#      10 import numbers
#      11
#
# AttributeError: module 'skimage' has no attribute 'color'

# %%
#Input image dimensions.
#input_shape = x_train.shape[1:]

# Normalize data.
#x_train = x_train.astype('float32') / 255
#x_test = x_test.astype('float32') / 255

#x=y_train.shape[0]

# %%
preds = model.predict(x)
class_idx = np.argmax(preds[0])
print(class_idx)
class_output = model.output[:, class_idx]
last_conv_layer = model.get_layer("batch_normalization_259")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-31fe70a34955> in <module>()
# ----> 1 preds = model.predict(x)
#       2 class_idx = np.argmax(preds[0])
#       3 print(class_idx)
#       4 class_output = model.output[:, class_idx]
#       5 last_conv_layer = model.get_layer("batch_normalization_259")
#
# NameError: name 'model' is not defined

# %%
grads = K.gradients(class_output, last_conv_layer.output)[0]
print(grads.shape)
pooled_grads = K.mean(grads, axis=(0, 1, 2))
print(pooled_grads.shape)
iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])

pooled_grads_value, conv_layer_output_value = iterate([x])

for i in range(512):
  conv_layer_output_value[:, :, i] *= pooled_grads_value[i]

# %%
heatmap = np.mean(conv_layer_output_value, axis = -1)
print(conv_layer_output_value.shape)
print(heatmap.shape)
heatmap = np.maximum(heatmap, 0)
heatmap /= np.max(heatmap)

# %%
heatmap = cv2.resize(heatmap, (img1.shape[1], img1.shape[0]))
heatmap = np.uint8(255 * heatmap)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
superimposed_img = cv2.addWeighted(img1, 0.5, heatmap, 0.5, 0)
#from google.colab.patches import cv2_imshow
cv2_imshow(img1)
cv2_imshow(superimposed_img)
